# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
morts ={
    "One mile by jet": 1/1000,
    "One mile walking": 1/17,
    "One mile by car": 1/250,
    "One mile by train": 1/6000,
    "One skydive": 8,
    # "One mile by GA": 5e-3
}

# %%
fig,ax = plt.subplots(1,1)

ax.bar(morts.keys(), morts.values())
ax.set_yscale('symlog')

# %%
sns.barplot(morts.keys(), morts.values())
# Out:
# C:\ANACON~1\envs\sandbox\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 sns.barplot(morts.keys(), morts.values())
#
# File C:\ANACON~1\envs\sandbox\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
# ...
